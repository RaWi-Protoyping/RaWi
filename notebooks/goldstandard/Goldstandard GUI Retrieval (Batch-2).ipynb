# %% [markdown]
# # 1. Merge Query Batches

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 5000)
pd.set_option('display.max_colwidth', 5000)

# %%
abs_path = '../data/gui_ranking/mturk/goldstandard_batch_2/02_query_results/'

batch_1 = pd.read_csv(abs_path+"batch_results_1.csv")
batch_2 = pd.read_csv(abs_path+"batch_results_2.csv")
batch_3 = pd.read_csv(abs_path+"batch_results_3.csv")
batch_4 = pd.read_csv(abs_path+"batch_results_4.csv")

batches = pd.concat([batch_1, batch_2, batch_3, batch_4])

# %%
batch = batches[['WorkerId', 'Answer.summary', 'Input.gui_index']].copy()
batch = batch.rename(columns={"Answer.summary": "query", "Input.gui_index": "gui_index"})

# %% [markdown]
# # 2. Preprocess Queries

# %%
def dequote(s):
    """
    If a string has single or double quotes around it, remove them.
    Make sure the pair of quotes match.
    If a matching pair of quotes is not found, return the string unchanged.
    """
    if (s[0] == s[-1]) and s.startswith(("'", '"')):
        return s[1:-1]
    return s

def strip_special_chars(s):
    import re
    s = re.sub(r"^\W+", "", s)
    s = re.sub(r"\W+$", "", s)
    return s

def preprocess(s):
    s = s.strip()
    s = strip_special_chars(s)
    s = s.strip()
    return s

# %%
# Preprocess the queries
batch["query"] = batch.apply(lambda row: (preprocess(row["query"])), axis=1)

# %% [markdown]
# # 3. Filter Queries

# %%
print("Size before filtering: {}".format(len(batch)))
print("Unique workers: {}".format(len(set([elem[0] for elem in batch[["WorkerId"]].values.tolist()]))))
# Out:
# Size before filtering: 1045
# Unique workers: 56

# %%
# WorkerIds that should be filtered since they systematically made errors
worker_ids = ["A11LV5AT27LBFI", "A373WQWN0DADNL", "A1966JFRA8OWUW", "A5YAOZYSJBF5J", "A3KECU88OW1KNB", "A3AFAUMZ4AULZF"]

# %%
# Filter batches from bad workers
filtered_batch = batch.loc[~batch['WorkerId'].isin(worker_ids)].copy()

# %%
# Filter single GUIs that are obvisouly errorneous from Rico (e.g. blank or black screen)
gui_ids_to_filter = [62645, 51144, 48115, 5573, 30665, 65339, 62736]

# %%
# Filter batches from bad GUIs
filtered_batch = filtered_batch.loc[~filtered_batch['gui_index'].isin(gui_ids_to_filter)].copy()

# %%
print("Size after filtering: {}".format(len(filtered_batch)))
print("Unique workers after filtering: {}".format(len(set([elem[0] for elem in filtered_batch[["WorkerId"]].values.tolist()]))))
# Out:
# Size after filtering: 930
# Unique workers after filtering: 50

# %%
# Load the queries from the previous batch to exclude them from the second batch
abs_path_gs =  '../data/gui_ranking/mturk/goldstandard_batch_1/03_query_sampled/goldstandard_qgw.csv'
goldstandard_sample = pd.read_csv(abs_path_gs, index_col=0)

# %% [markdown]
# # 4. Gold Standard Queries

# %%
print('Size all data: {}'.format(len(filtered_batch)))
print('Size goldstandard: {}'.format(len(goldstandard_sample)))
filtered_batch_updated = pd.concat([filtered_batch, goldstandard_sample]).drop_duplicates(keep=False)
print('Size remaining data: {}'.format(len(filtered_batch_updated)))
# Out:
# Size all data: 930
# Size goldstandard: 150
# Size remaining data: 780

# %%
# Select random sample from the remaining dataset for the second batch
goldstandard_size_n = 300
goldstandard_random_state = 537
goldstandard_sample = filtered_batch_updated.sample(n=goldstandard_size_n, random_state=goldstandard_random_state)

# %%
print("Goldstandard size: {}".format(len(goldstandard_sample)))
print("Number of unique workers: {}".format(len(goldstandard_sample["WorkerId"].unique())))
goldstandard_sample
# Out:
# Goldstandard size: 300
# Number of unique workers: 50
#            WorkerId                                                                                                                 query  gui_index
# 72   A1CLIAQI9N8YOJ                                                                    app for football team players overview with videos       5478
# 259   ASL3NA8PT15JU                                                                                             Call logs with no history      46731
# 297  A2TXLKAOJJ9BEK                                                                                   page contain the searchbar for song      64908
# 392  A1FV1XP2UU0EVH                                                                                                  expandable side menu       6565
# 142  A218PYL0KI07IO                                                                                  Good restaurants for Valentine's day      60496
# 253   AVRMXTZHUCXXL                                                                                                     Events estimation      45130
# 39   A1CLIAQI9N8YOJ                                                                                      French appl for traffic stations      10002
# 145   ABOC5IITA7DV1     Search a flight by providing the provenance, destination, number of ways, date you intend to travel and the class        387
# 101  A32ATJF7ZENBWH                                                                         photo preview app with zoomIn zoomOut options      39626
# 176  A1QOJGSZEZXSE1                                                                                              List Item with Tab Color      67394
# 309   AFWYEWB3W0ZSB                                                           search bar with list of  connecters name ,favorites and all      43096
# 439  A1FV1XP2UU0EVH                                                                                                          login screen      49706
# 53    A8BH4CXKWP6PW                                                                                                 test article, options      46234
# 396   ASL3NA8PT15JU                                                                                              Womens sexual healthcare      22864
# 99   A1P9OU1YPIQVW7                                                    Sign-in with Facebook data in which name or email address included      36127
# 314  A1UOWWUH9WVUOH                                                                                             old facebook sign up page      50769
# 285  A12EE9K9VY7XXF                                                                                             Text insert with keyboard      33506
# 154  A13HTFAO25P3U4                                                                                             Settings with regionbnews      49255
# 134  A27GOFWHEHV758                                                                                                          start screen      39774
# 353  A1QOJGSZEZXSE1                                                                 Search icon with Menu and Chat Icon and advertisement      30371
# 82    A8BH4CXKWP6PW                                                                                                    sign up with email      31541
# 109  A32ATJF7ZENBWH                                                                                            sign up with welcome Bonus      34735
# 16   A2TXLKAOJJ9BEK                                                                                    It display the Map with search bar      61599
# 115  A2TXLKAOJJ9BEK                                                                          page contaion the current and saved location      58357
# 295  A3BXLWKSBUO002                                                                                       Details about cards and numbers      43707
# 65   A13HTFAO25P3U4                                                                                 App for jokes and funny image posting      53353
# 5    A3HN5JOPRIKMNU                                                                                      screen with select single answer      37856
# 379  A2TXLKAOJJ9BEK                                                                                                     terms of chocoapp      45906
# 234   ABREXWFU9D3WR                                                                                 a sreen to enter the personal details      27474
# 3    A26BOJ0O91EIBR                                                         Price comparison application showing discounts and chash back       6928
# 237   AFWYEWB3W0ZSB                                                                                  Account creation with selection menu      23798
# 18   A3CR6XU8373Z2N                                                                                                                 alarm      35918
# 84     AE2M19TCQJWI                                                                                                        RN Mentor Quiz      54284
# 318  A26BOJ0O91EIBR                                                                           In car USB connection with eService and UVO      19566
# 144    AE2M19TCQJWI                                                                                 List of blocked accounts and contacts      35058
# 154  A3CP44KT0KLT69                                                        menu to choose between different options for organising ebooks       5231
# 413  A1NFUUQF4T9KXM                                                                                        adjust actions in the settings      41466
# 159  A13HTFAO25P3U4                                                                                                  Country code listing       7300
# 94   A23IXWZNWDLTNT                                                                                                 sign up for baby care      52122
# 141  A26BOJ0O91EIBR                                                     Searching Engine with search bar for phrases starting with How to      26423
# 81    AFWTKS209SFQY                                                                                                       search location      52330
# 316  A3CUDF4JR3QTS4                                                                                 list with favorite button and Ads bar      21912
# 95   A1CLIAQI9N8YOJ                                                            weather and forecasting app with weather station selection      56692
# 140  A3CUDF4JR3QTS4                                                                                                          video editor      18234
# 229   A8BH4CXKWP6PW                                                                                         buy item, image recorder, ads      40061
# 80   A11B0Q26E3U79M                                                              web advertising for an app with continue and skip button       1942
# 189  A1QOJGSZEZXSE1                                                    Collapsible and Expandable List with Navigation bar and Fix Header       3183
# 275    AE2M19TCQJWI                                                                                       Mobile Bible Reader Application      12789
# 333  A1V8T0ZHN29U5H                                                                                          Japanese anime books and ads      50541
# 427  A1V8T0ZHN29U5H                                                                                             food and restaurants list      66329
# 372  A3NDKVYPTBWPEO                                                                           downloading the image with brief dscription      68091
# 8    A23IXWZNWDLTNT                                                                                                        top world news       5167
# 81     AE2M19TCQJWI                                                                                                       Model Selection       4616
# 366  A34Z73OAWYW014                                                                                            Search with search results      52196
# 246  A1FV1XP2UU0EVH                                                                                                         Settings menu       1217
# 59   A3CR6XU8373Z2N                                                                                           selecting different devices      39281
# 57   A13HTFAO25P3U4                                                                                             Microsoft corp with stock      30461
# 112   A6KII16FVGPFF                                                                                                  latest keypad themes      21480
# 233  A1250SSIMRQ3JA                                                                                                              PitchLab      27641
# 241  A1UOWWUH9WVUOH                                                                                             feedback bar in PayNearMe      53870
# 150  A32ATJF7ZENBWH                                             search bar with results in Science, Textbook Solutions and Online Tuition      42111
# 76   A20EIK9C477PTC                                                                                                                cheese      64438
# 298  A23IXWZNWDLTNT                                                                                          cell phone storage structure      62027
# 248  A3CUDF4JR3QTS4                                                                             book reader with "Become a Member" button      40696
# 123  A3HN5JOPRIKMNU                                                                                weather application screen's side menu      51829
# 130  A3TTSFVAJHM947                               Trivago-Threats of pandemic and climate change an 'opportunity' to enhance local travel      33084
# 110  A3HN5JOPRIKMNU                                                                           podcast episode screen with download option      47138
# 33   A1WH1CTOZHV7YR                                                                             information description with login button      13352
# 227  A11B0Q26E3U79M                                                                Menu for a music player app with ten different buttons      71867
# 349   ASL3NA8PT15JU                                                                                    select which sports news to appear      18949
# 51    AFWTKS209SFQY                                   search bar with shopping categories, discount advertisement and account maintenance        833
# 64   A34Z73OAWYW014                                                                                                      News with detail      39546
# 4    A23IXWZNWDLTNT                                                                                                  learn english easily      23185
# 12   A3HN5JOPRIKMNU                                                                                   Dropdown options in ascending order      71586
# 42   A23IXWZNWDLTNT                                                                                                find your life partner      24661
# 161   A6KII16FVGPFF                                                                             how can i find the best personal servises      56562
# 296  A2KNN0T650FQ01                                                                                                    photography filter       8879
# 146  A27GOFWHEHV758                                                                                             privacy policy aceptacion       2076
# 6    A1FV1XP2UU0EVH                                                                                                           Main screen      68694
# 443  A3G2CWQ5OV8AHE                                                           FAQ YapStone support search button and missing site message      36059
# 341  A3CUDF4JR3QTS4                                                                                   location map window with search bar      25717
# 279   AFWTKS209SFQY                                                                                                         Image editing      24881
# 388  A23IXWZNWDLTNT                                                                                                  JO-ANN GUI interface      46803
# 155  A1NW9UWTFS14S5                                                                                          Advert for weather reporting      43850
# 246  A3TTSFVAJHM947                                                                         Settings for network usuage-bahaviour-history      19860
# 373   A8PRJZR3J6UTF                                                                                 camera purchase reviews for beginners       8601
# 3    A2G11CAPXX5616                                                                                   list of data with image and details      25117
# 305   AFWTKS209SFQY                                                                            search bar with various categories of GIFs      57835
# 441  A1UOWWUH9WVUOH                                                                                            search for works in  a map      39682
# 31    AFWYEWB3W0ZSB                                                                   search bar with  list of application with its image      61954
# 65   A1V8T0ZHN29U5H                                                                                        blood glucose tracker side bar      47499
# 48   A34Z73OAWYW014                                                                                            Post results with postings      29061
# 41   A1UOWWUH9WVUOH                                                                        sharing hair care tips through various mediums      71288
# 198  A1QOJGSZEZXSE1                                                     Close Button and Image Grid with Image card and Plus Icon overlay      41568
# 137  A36COHZCHGHYD3                                                               Setting of notification with label, time, when and days      22867
# 224   AFWTKS209SFQY                                                     veggie medley salad recipe with nutrition and serving information      70042
# 450  A3CUDF4JR3QTS4                                                                                               four tabs with calander      15688
# 190  A3IP4RARMM3X4A                                                                                         Registration for the services      11918
# 215  A1UOWWUH9WVUOH                                                                                       share prompt  for a fitness app      53967
# 317  A3CP44KT0KLT69                                                    Filter settings for choosing price range, number of beds and baths      42503
# 9    A2KNN0T650FQ01                                                                                                          learning app      28141
# 150  A1NW9UWTFS14S5                                                                         table with information about controls on foot      60323
# 141  A1250SSIMRQ3JA                                                                                                           Weather app      36651
# 149  A2TXLKAOJJ9BEK                                                                                           loading page of happy hours      26963
# 379   AFWYEWB3W0ZSB                                                       search bar with result list showing song preview image and name      67905
# 265  A1CLIAQI9N8YOJ                                                                                  Tennis championships players ranking      43130
# 86   A1WH1CTOZHV7YR                                                                         blood test with data entry and unit selection      25151
# 321  A20EIK9C477PTC                                                                                                             bloomberg      49462
# 46   A34Z73OAWYW014                                                                                              Translation with results      16357
# 249  A1R6ELRI4GR9XF                                                                                        search bar with add a favorite      30002
# 270  A1JBSNWSI7VKQO                                                                                                           Music Album       4973
# 76   A3G2CWQ5OV8AHE                                        feedback request, whether you like it, with options yes or feedback and emojis       4707
# 67    ASL3NA8PT15JU                                                                                        Travel with ease with tracking       7899
# 213  A2TXLKAOJJ9BEK                                                                                            search page of dolphin.com       7152
# 15   A1UOWWUH9WVUOH                                                                                    prompt to add a suite to  Wishlist      18297
# 380  A2TXLKAOJJ9BEK                                                                              home page of dictionary with word of day      16110
# 18    AFWTKS209SFQY                                                                                                unknown album playlist      39515
# 288  A1UOWWUH9WVUOH                                                                                    maternity scheduler with timetable      14230
# 240  A2TXLKAOJJ9BEK                                                                          map display the error of voice recognization       9246
# 6     A6KII16FVGPFF                                                                                        how can i change this settings      52964
# 307   ABOC5IITA7DV1                                                                  Search bar with a text and a page showing no results      67718
# 304  A2KNN0T650FQ01                                                                                                     shopping list app        922
# 23   A11B0Q26E3U79M                                                             Information screen to add a tabatas in a tabatas list app      49331
# 245  A1FV1XP2UU0EVH                                                                                            login screen, landing page        879
# 18   A2G11CAPXX5616                                                                                                 UI for reminder notes       4413
# 287  A1NW9UWTFS14S5                                                                              e-commerce for online selling and buying      70937
# 375  A1NW9UWTFS14S5                                                                                                          Options menu      34240
# 89   A1QOJGSZEZXSE1                                                                             Card with image and text with link button      51118
# 252   AV5170KNIBKL6                                                                                   reader's view of an article of Time      50666
# 338  A1UOWWUH9WVUOH                                                                                 sign up page for a dating application      23576
# 135  A1CLIAQI9N8YOJ                                                                         Forum app to meet people and join discussions      70594
# 283  A3T1ZTIWDIOXMX                                                News with result list showing items such as Bitcoin Magazine, CoinDesk      34473
# 411  A3CUDF4JR3QTS4                                                                                countdown timer with a list of options      57318
# 105  A1FV1XP2UU0EVH                                                                                                       select location      69822
# 104   AFWTKS209SFQY                                                                                 search job locations in desired place      38323
# 127  A1QOJGSZEZXSE1                                        dropdown for country and text box for contact number with number only keyboard      33194
# 151  A1NW9UWTFS14S5                                                                                      Weekday digest for meal planning       6044
# 144    AE2M19TCQJWI                                                                                                 T20 Cricket Live Chat      61947
# 242  A1UOWWUH9WVUOH                                                                              2D graph with a point and its dimensions      61057
# 60   A23IXWZNWDLTNT                                                                                                 sharing files service      53377
# 409  A1NW9UWTFS14S5                                                                                       Job feed for online job posting      38318
# 82   A3CUDF4JR3QTS4                                                                                           Text window wth search tool      71819
# 324  A1NW9UWTFS14S5                                                                                                 List of notifications      47119
# 196  A1JBSNWSI7VKQO                                                         App for Journey from one place to another , booking the seats      43369
# 231   A8BH4CXKWP6PW                                                                             research of specific year, month, and day       3390
# 102   AFWTKS209SFQY                                                       translation from chinese to english with favorites word storage      35168
# 248  A12EE9K9VY7XXF                                                                 Settings with account, alert frequency and alert type      38321
# 276  A3BXLWKSBUO002                                                                                        my net diary with many options       8337
# 96   A12EE9K9VY7XXF                                                                                                        Country picker      68533
# 393  A27GOFWHEHV758                                                                                              sharing privacy settings      38969
# 383   A6KII16FVGPFF                                                                                                   the best calculator      69034
# 105   A8PRJZR3J6UTF                                                                                  search bar with audio upload feature      33471
# 200  A1P9OU1YPIQVW7                                                                     sign-in with Google account with less information      48180
# 46   A1QOJGSZEZXSE1                           Filter Nav bar with Search icon, Cart, product name, product image, product rating and Menu      17175
# 151  A3NDKVYPTBWPEO                                                                              Listing the items with attractive images       9267
# 123  A2G11CAPXX5616                                                                                               Inbox design and themes      12059
# 342  A1R6ELRI4GR9XF                                                                                               google map with details      12353
# 207  A1250SSIMRQ3JA                                                                                                           Add blocker      56729
# 132  A1FV1XP2UU0EVH                                                                                                          login screen      43412
# 142  A3IP4RARMM3X4A                                                                                                         Find a barber      71571
# 7    A1JBSNWSI7VKQO                                                                                      Different Language choice keypad      45339
# 43   A2KNN0T650FQ01                                                                                           camera notification message      42512
# 244  A1NW9UWTFS14S5                                                                           Calendar with monthly layout for promotions      64069
# 127  A3CR6XU8373Z2N                                                                                                      see game history      56089
# 232  A3HN5JOPRIKMNU                                                               Menu should be in ascending order to make more friendly      64028
# 26   A12EE9K9VY7XXF                                                                                  List of chapers with name and status      64519
# 19   A3CP44KT0KLT69                                                                                                          photo viewer      31048
# 10   A2KNN0T650FQ01                                                                                                   us immigration news      18726
# 88     AE2M19TCQJWI                                                                                                      Weather Forecast       7725
# 78   A3CP44KT0KLT69                                                                                                  create notifications      52979
# 8     AFWTKS209SFQY                                                 app settings with permissions, notifications, phone numbers and about      46075
# 437  A2KNN0T650FQ01                                                                                                 loading screen on app      50768
# 262  A27GOFWHEHV758                                                                          infrormation screen about unavailble service      17620
# 83   A1JBSNWSI7VKQO                                                                                                   GPS Location finder      39575
# 266  A23IXWZNWDLTNT                                                                                             alarm to organize my work      61177
# 237  A36COHZCHGHYD3                Search bar with a searching function and entries like home, weather, traffic, radar, closings & delays      37419
# 35   A27GOFWHEHV758                                                                                        most viewed report of the week      47628
# 452  A1R6ELRI4GR9XF                                                                                       in shape water schedule by date      30327
# 116   ASL3NA8PT15JU                                                                                    elementary podcast British council      58308
# 22    AV5170KNIBKL6                                                   live breaking news video with another top stories article and video       5235
# 461  A1FV1XP2UU0EVH                                                                                                  expandable side menu      14215
# 228  A3CUDF4JR3QTS4                                                                                       voice changer with many buttons      45268
# 238  A1NFUUQF4T9KXM                                                                                                video show of a tattoo      51384
# 220  A11B0Q26E3U79M                                                                 Overview of a holiday room with pictures and features      41847
# 1    A3HN5JOPRIKMNU                                                ecommerce portal homescreen with search bar and frequently used option      53479
# 45   A2KNN0T650FQ01                                                                                                          login screen      45861
# 49   A34Z73OAWYW014                                                                                                Menu with menu options      40960
# 345   ASL3NA8PT15JU                                                                                                    Body care products      20162
# 180  A2JJQ4KXJCPDAW                                                                                                           word levels      36189
# 77   A1FV1XP2UU0EVH                                                                                                           bottom menu      47832
# 254  A1WH1CTOZHV7YR                                                                    privacy policy with types of collected information       8453
# 98   A1250SSIMRQ3JA                                                                                    Chinese emergency words in English      27561
# 382   A8BH4CXKWP6PW                                                                               Text reading,search bar, ads, and share      29775
# 284  A2KNN0T650FQ01                                                                                         recognizing plants by picture      49102
# 357   AQ6IZ8Q7EHQQE                                                                                      newsfeed with articles and image      67353
# 188  A26BOJ0O91EIBR                                                 DealNews application with sign in, feedback, top deals and categories      38384
# 259  A1NFUUQF4T9KXM                                                                                         informations about Grace Chan      17255
# 292  A23IXWZNWDLTNT                                                                                           income and expenses reports      26054
# 371  A20EIK9C477PTC                                                                                                                 lists       5436
# 17   A1FV1XP2UU0EVH                                                                                                  expandable side menu      12792
# 269  A1CLIAQI9N8YOJ                                                                                              spin and win rewards app      47945
# 332  A27GOFWHEHV758                                                                                                     channels overview      62180
# 397  A1CLIAQI9N8YOJ                                                                              shopping lists app with ability to share       4783
# 254  A2TXLKAOJJ9BEK                                                                         song with the artist picture and pause button      45243
# 256  A1V8T0ZHN29U5H                                                                                 meet peopple feature me women selfies      50320
# 406  A1JBSNWSI7VKQO                                                                                                       A list of Games       1309
# 63   A2TXLKAOJJ9BEK                                                                   search bar that include the dish and resturent name       4793
# 48   A1FV1XP2UU0EVH                                                                                                           pop up menu      19063
# 125  A1WH1CTOZHV7YR                                                                playlists overview with favorites and playlistis names      44035
# 320  A1R6ELRI4GR9XF                                                                                          information with get started      52301
# 99   A3NDKVYPTBWPEO                                                                          Details listed with all the Major Satellites      42375
# 223   AFWYEWB3W0ZSB                                                                                                   keypad dialer theme      40339
# 425   AV5170KNIBKL6                                                                                           search coffee with location       2696
# 51   A11B0Q26E3U79M                                                                                       Web advertising for online shop      43530
# 290  A3CR6XU8373Z2N                                                                                                        various emojis      62124
# 174  A23IXWZNWDLTNT                                                                                                            rent a car      32444
# 247  A23IXWZNWDLTNT                                                                                               Units to measure volume      72081
# 83   A34Z73OAWYW014                                                                                                     choose a location      40965
# 66   A1UOWWUH9WVUOH                                                     creating profile with  email using username email id and password      40816
# 261   AFWTKS209SFQY                                                                                                     open garden forum      17677
# 256  A3IP4RARMM3X4A                                                                                                      News with videos      18890
# 271  A3CR6XU8373Z2N                                                                                  picture of a robot with explanations      25996
# 231  A11B0Q26E3U79M                                                                                                 Login Scren of an app      25425
# 243  A3BXLWKSBUO002                                                                                              a news with a share icon      21244
# 63    A8PRJZR3J6UTF                                                                              food tutorial apps with background music      61223
# 26   A2NA5304C0C5FQ                                                                       Android application typical notification window      52436
# 278  A218PYL0KI07IO                                                                                       Booking a lounge at the airport      57682
# 391  A3G2CWQ5OV8AHE                                                                                          overview of livestream shows      24998
# 436  A2KNN0T650FQ01                                                                                                 language learning app      27741
# 335   AVRMXTZHUCXXL                                                                                               flag and find locations      51158
# 73   A1UOWWUH9WVUOH                                                                            Chinese dating app describing its features      56919
# 170   AFWTKS209SFQY                                                                                         Navigation and settings panel       4895
# 166  A13HTFAO25P3U4                                                                                                       Yalla shoot app      54720
# 420  A1NFUUQF4T9KXM                                                                                                     down nearby picks      31953
# 61   A3BXLWKSBUO002                                                                                           a news and an advertisement      56632
# 40    A8BH4CXKWP6PW                                                                                        Most demanded news and article       7762
# 86   A1FV1XP2UU0EVH                                                                                                   shopping categories      37710
# 197  A2G11CAPXX5616                                                                                           Mobile UI for settings page      64671
# 2     A6KII16FVGPFF                                                                                                  today storms updates      69974
# 71   A1250SSIMRQ3JA                                                                                              Mp3 + player +  software      39444
# 70   A1V8T0ZHN29U5H                                                                                          history of experienced staff      14251
# 418  A1CLIAQI9N8YOJ                                                                                                broadcasting sport app      51474
# 168  A1NW9UWTFS14S5                                                                                            Tabs for exams and grading      49646
# 399  A1250SSIMRQ3JA                                                                                                              NBC news      37500
# 126   ABREXWFU9D3WR                                                               screen with different measurements of a women's picture      66134
# 171  A3BXLWKSBUO002                                                                                   ingredients of crust less breakfast       7928
# 350  A1NFUUQF4T9KXM                                                                                                       a list of songs      61929
# 329   AV5170KNIBKL6                                                                             share news with another shareable options      45216
# 28   A12EE9K9VY7XXF                                                                                             List of states and a menu       6622
# 212  A3HN5JOPRIKMNU                                                                           This is good example for information screen       7465
# 108  A26BOJ0O91EIBR                                                                            Wildlife NEWS overview with video and text      13880
# 33   A3NDKVYPTBWPEO                                                                  search bar with key words under specified categories      56905
# 4    A11B0Q26E3U79M                                                       screen of a task manager showing open tasks of the mobile phone      62586
# 118  A1NW9UWTFS14S5                                                                                      Introductory message for startup      52920
# 258  A23IXWZNWDLTNT                                                                                                       sign up to ASOS       4322
# 148  A32ATJF7ZENBWH                             Map app with the ability of sharing the location with different social media applications      40412
# 109  A3TTSFVAJHM947                          Sign in with Twitter-allows Twitter users to enjoy the benefits of a registered user account      66815
# 4     AV5170KNIBKL6                                                                                       text editing with their options       4396
# 87    A8PRJZR3J6UTF                                                                             guitar lessons app for left handed people      38823
# 163   AQ6IZ8Q7EHQQE                                                                              emoticons of yellow faces to choose from      30432
# 309  A27GOFWHEHV758                                                                                                       game user guide      12609
# 43   A1R6ELRI4GR9XF                                                                                           food photo with ingredients      42425
# 195  A2TXLKAOJJ9BEK                                                      App that display the shop and store locators and account details      63776
# 14   A1WH1CTOZHV7YR                                                                                   gaming tickets with account manager      39559
# 308  A1CLIAQI9N8YOJ                                                                                              countries-based news app      25210
# 331  A12EE9K9VY7XXF                                                                                           List of dropdown categories      67401
# 343  A3BXLWKSBUO002                                                                           a pop up window to choose in which to share      13855
# 45   A1R6ELRI4GR9XF                                                                                            google map with search bar      24749
# 328  A3T1ZTIWDIOXMX  search bar with result a list showing person with name, adress, price and image, with option call now or send enqury      19885
# 463  A1R6ELRI4GR9XF                                                                  choose primary use for cash for personal or business      32392
# 24   A2NA5304C0C5FQ                                Confirmation dialogue box for switching application with option to proceed and go back      21297
# 97   A1WH1CTOZHV7YR                                                                              video review with send as message button      44177
# 201   AV5170KNIBKL6                                                                          playlists with other options in music player      25514
# 311  A36COHZCHGHYD3                                                                                                    Team selection bar      43148
# 76   A3IP4RARMM3X4A                                                                                  Tutorial for newly installed browser      65334
# 32   A2G11CAPXX5616                                                                                              Translation page with UI      70252
# 273  A3CUDF4JR3QTS4                                                                                              list of football players      17533
# 8    A12EE9K9VY7XXF                                                                         Login with organitzation address and password      51947
# 385  A2TXLKAOJJ9BEK                                                                                Tickets website show the register page      35976
# 53   A36COHZCHGHYD3                                                       Registration with email, full name, public username and country      40401
# 1     AFWYEWB3W0ZSB                                                                                               Review with description      33340
# 102  A26BOJ0O91EIBR                                                Site showing papers with Title, Release date, advisory ID, and Summary      41528
# 31   A3HN5JOPRIKMNU                                                              Application screen for find the phone number information      15516
# 28   A27GOFWHEHV758                                                                                                      low carbs shakes      65741
# 163  A34Z73OAWYW014                                                                                            Invitation with share link      46292
# 208   ABREXWFU9D3WR                                                                                   a language window with many options      70036
# 97   A3CR6XU8373Z2N                                                                                                                   fun      17201
# 12   A3NDKVYPTBWPEO                                                         Search bar with attractive pictures as well as date and names      46612
# 401  A2G11CAPXX5616                                                                                            Login form with validation      59701
# 0    A26BOJ0O91EIBR                                                             Application with writing reviews, bookmarks, and invoices      48513
# 26   A3HN5JOPRIKMNU                                                                                        request for application update      54682
# 104   A6KII16FVGPFF                                                                                                   moblie locking apps      19109
# 444  A3CUDF4JR3QTS4                                                 profile window with a button to take a photo or select it from galary      38535
# 131  A1NW9UWTFS14S5                                                                                                details for disclaimer      28675
# 139  A36COHZCHGHYD3      Start screen of a photo editing program with buttons like your photos, use camera, from facebook and cool photos      50679
# 267    AE2M19TCQJWI                                                         Great American Ball Park Tickets Booking and Schedule Updates      36046
# 230  A3HN5JOPRIKMNU                                                                                      Sign up screen with user details       8109
# 96   A3CR6XU8373Z2N                                                                                             buying many items at once      38078
# 62     AE2M19TCQJWI                                                                                                    Personalised Timer      35384
# 355  A3NDKVYPTBWPEO                                          search bar with contact list with profile picture and all other applications      47542

# %%
# Save goldstandard to csv files
abs_path_save =  '../data/gui_ranking/mturk/goldstandard_batch_2/03_query_sampled/'
goldstandard_sample[["query"]].to_csv(abs_path_save+"goldstandard_q.csv", index_label="id")
goldstandard_sample[["query", "WorkerId"]].to_csv(abs_path_save+"goldstandard_qw.csv", index_label="id")
goldstandard_sample[["query", "gui_index"]].to_csv(abs_path_save+"goldstandard_qg.csv", index_label="id")
goldstandard_sample[["query", "gui_index", "WorkerId"]].to_csv(abs_path_save+"goldstandard_qgw.csv", index_label="id")

# %% [markdown]
# # 5. Load and Pool Top-30 GUIs from Baseline Rankers

# %% [markdown]
# ### 5.1 Compute Pooling Metrics

# %%
# We generated the top-30 guis with different methods and perform pooling to get initial set of guis to be annotated
abs_path = '../data/gui_ranking/mturk/goldstandard_batch_2/04_baseline_rankings/'

from ast import literal_eval

rankings_bm25 = pd.read_csv(abs_path+"/bm25okapi/rankings_bm25okapi.csv")
rankings_bm25['ranked_guis'] = rankings_bm25['ranked_guis'].apply(literal_eval)

rankings_tfidf = pd.read_csv(abs_path+"/tfidf-retrieval/rankings_tfidf-retrieval.csv")
rankings_tfidf['ranked_guis'] = rankings_tfidf['ranked_guis'].apply(literal_eval)

rankings_iwcs = pd.read_csv(abs_path+"/nbow/rankings_nbow.csv")
rankings_iwcs['ranked_guis'] = rankings_iwcs['ranked_guis'].apply(literal_eval)

# %%
rankings_goldstandard = pd.DataFrame()
rankings_goldstandard = rankings_goldstandard.append(rankings_bm25[["id", "query", "ranked_guis"]])
rankings_goldstandard = rankings_goldstandard.rename({"ranked_guis": "rankings_1"}, axis=1)
rankings_goldstandard["rankings_2"] = rankings_tfidf[["ranked_guis"]]
rankings_goldstandard["rankings_3"] = rankings_iwcs[["ranked_guis"]]

# %%
def pool_all(rankings_1, rankings_2, rankings_3):
    rankings = rankings_1.copy()
    rankings.extend(rankings_2)
    rankings.extend(rankings_3)
    return list(set(rankings))

def pairwise_overlap_ratio(rankings_1, rankings_2):
    ranks_1 = rankings_1.copy()
    ranks_2 = rankings_2.copy()
    return 1 - len(set(ranks_1 + ranks_2))/ len(ranks_1 + ranks_2)

def all_overlap_ratio(rankings_1, rankings_2, rankings_3):
    ranks_1 = rankings_1.copy()
    ranks_2 = rankings_2.copy()
    ranks_3 = rankings_3.copy()
    return 1 - (len(set(ranks_1 + ranks_2 + ranks_3))/ len(ranks_1 + ranks_2 + ranks_3))

# %%
rankings_goldstandard["merged_rankings"] = rankings_goldstandard.apply(lambda row: pool_all(row["rankings_1"], row["rankings_2"], row["rankings_3"]), axis=1)
rankings_goldstandard["size_1"] = rankings_goldstandard.apply(lambda row: len(row["rankings_1"]), axis=1)
rankings_goldstandard["size_2"] = rankings_goldstandard.apply(lambda row: len(row["rankings_2"]), axis=1)
rankings_goldstandard["size_3"] = rankings_goldstandard.apply(lambda row: len(row["rankings_3"]), axis=1)
rankings_goldstandard["size_pooled"] = rankings_goldstandard.apply(lambda row: len(row["merged_rankings"]), axis=1)
rankings_goldstandard["olr_1_2"] = rankings_goldstandard.apply(lambda row: pairwise_overlap_ratio(row["rankings_1"], row["rankings_2"]), axis=1)
rankings_goldstandard["olr_1_3"] = rankings_goldstandard.apply(lambda row: pairwise_overlap_ratio(row["rankings_1"], row["rankings_3"]), axis=1)
rankings_goldstandard["olr_2_3"] = rankings_goldstandard.apply(lambda row: pairwise_overlap_ratio(row["rankings_2"], row["rankings_3"]), axis=1)
rankings_goldstandard["olr_all"] = rankings_goldstandard.apply(lambda row: all_overlap_ratio(row["rankings_1"], row["rankings_2"], row["rankings_3"]), axis=1)

# %% [markdown]
# ### 5.2 Pooled Top-30 GUIs from Baseline Models

# %%
def pool_top_results(row, pool_size=30, shuffle_pool=True, shuffle_seed=471):
    pool = []
    rankings_1 = row['rankings_1'].copy()
    rankings_2 = row['rankings_2'].copy()
    rankings_3 = row['rankings_3'].copy()
    all_rankings = [rankings_1, rankings_2, rankings_3]
    # First add the GUI to the pool that we showed the worker to initially write the query
    gui_shown_to_write_query = rankings_1[len(rankings_1)-1]
    pool.append(gui_shown_to_write_query)
    pool_counter = 0
    while len(pool) < pool_size:
        curr_ranking = all_rankings[pool_counter%3]
        if curr_ranking:
            curr_elem = curr_ranking.pop(0)
            while curr_elem in pool and curr_ranking:
                curr_elem = curr_ranking.pop(0)
            pool.append(curr_elem)
        pool_counter+=1
    if shuffle_pool:
        random.Random(shuffle_seed).shuffle(pool)
    return pool

# %%
import random

SHUFFLE_POOLED_RANKINGS = False
SHUFFLE_SEED = 471

rankings_goldstandard["pooled_rankings"] = rankings_goldstandard.apply(lambda row: pool_top_results(row, shuffle_pool=SHUFFLE_POOLED_RANKINGS), axis=1)

# %%
rankings_goldstandard.to_csv(abs_path+"pooled_rankings.csv")

# %% [markdown]
# ### 5.3 Split Into Two Dataframes for MTurk

# %%
rankings_goldstandard_minified = rankings_goldstandard[["id", "query", "pooled_rankings"]].copy()

# %%
rankings_goldstandard_minified_1 = rankings_goldstandard_minified.copy()
rankings_goldstandard_minified_1["pooled_rankings"] = rankings_goldstandard_minified_1.apply(lambda row: row["pooled_rankings"][:int(len(row["pooled_rankings"])/2)], axis=1)
rankings_goldstandard_minified_2 = rankings_goldstandard_minified.copy()
rankings_goldstandard_minified_2["pooled_rankings"] = rankings_goldstandard_minified_2.apply(lambda row: row["pooled_rankings"][int(len(row["pooled_rankings"])/2):], axis=1)

# %%
f = lambda x: 'gui_index_{}'.format(x + 1)
rankings_goldstandard_minified_1_mturk = pd.concat([rankings_goldstandard_minified_1["id"], rankings_goldstandard_minified_1["query"], pd.DataFrame(rankings_goldstandard_minified_1["pooled_rankings"].values.tolist()).rename(columns=f)], axis=1)

# %%
rankings_goldstandard_minified_2_mturk = pd.concat([rankings_goldstandard_minified_2["id"], rankings_goldstandard_minified_2["query"], pd.DataFrame(rankings_goldstandard_minified_2["pooled_rankings"].values.tolist()).rename(columns=f)], axis=1)

# %%
abs_path = '../data/gui_ranking/mturk/goldstandard_batch_2/04_baseline_rankings/pooling/'

rankings_goldstandard.to_csv(abs_path+"pooled_rankings.csv", index=False)
# Save the pooled GUIs to CSV in the format that MTurk expects
rankings_goldstandard_minified_1_mturk.to_csv(abs_path+"pooled_rankings_for_mturk_1.csv", index=False)
rankings_goldstandard_minified_2_mturk.to_csv(abs_path+"pooled_rankings_for_mturk_2.csv", index=False)

# %% [markdown]
# # 6. Gold Standard Relevance Annotations

# %%
# Load annotations from MTurk
abs_path = '../data/gui_ranking/mturk/goldstandard_batch_2/05_relevance_annotations/'

annotations_1 = pd.read_csv(abs_path+"/annotations_1.csv")
annotations_2 = pd.read_csv(abs_path+"/annotations_2.csv")

# %% [markdown]
# ### 6.1 Preprocess

# %%
def annotations_to_list(row):
    annotations = []
    for i in range(1,16):
        prefix = 'Answer.gui_' + str(i)
        annotations.append([j for j in range(0,3) if row[prefix+"."+str(j)]][0])
    return annotations

def guis_indexes_to_list(row):
    gui_indexes = []
    for i in range(1,16):
        prefix = 'Input.gui_index_' + str(i)
        gui_indexes.append(row[prefix])
    return gui_indexes

# %%
def preprocess_annotations(dataframe):
    dataframe["annotations_list"] = dataframe.apply(lambda row: annotations_to_list(row), axis=1)
    dataframe["gui_indexes_list"] = dataframe.apply(lambda row: guis_indexes_to_list(row), axis=1)
    return dataframe

# %%
annotations_1 = preprocess_annotations(annotations_1)
annotations_2 = preprocess_annotations(annotations_2)

# %% [markdown]
# ### 6.2 Compute Majority Vote

# %%
from collections import Counter

def majority_vote_gui(votes):
    vote_count = Counter(votes)
    top_vote = vote_count.most_common(1)
    if top_vote[0][1] == 1:
        # We have a tie between the three options so we mark it with 3
        return 3
    return top_vote[0][0]

def majority_vote_hit(annotations):
    zipped = list(zip(*annotations))
    all_mvs = [majority_vote_gui(list(elem)) for elem in zipped]
    return all_mvs

# %%
annotations_minified_1 = annotations_1[["Input.query", "Input.id", "annotations_list", "gui_indexes_list", "WorkerId"]]

# %%
annotations_minified_2 = annotations_2[["Input.query", "Input.id", "annotations_list", "gui_indexes_list", "WorkerId"]]

# %%
def majority_votes_dataframe(dataframe):
    majority_votes = dataframe.copy()[["Input.id", "Input.query", "annotations_list", "gui_indexes_list"]].groupby(['Input.id', 'Input.query']).agg({
                                                                                                            
                                                                                                            "annotations_list": lambda x: majority_vote_hit(x.tolist()),
                                                                                                            "gui_indexes_list": lambda x: list(x)[0]})
    majority_votes = majority_votes.reset_index()
    majority_votes = majority_votes.rename({"Input.id": "id",
                                      "Input.query": "query",
                                      "annotations_list": "relevance",
                                      "gui_indexes_list": "gui_indexes"}, axis=1)
    return majority_votes

# %%
majority_votes_1 = majority_votes_dataframe(annotations_1)
majority_votes_2 = majority_votes_dataframe(annotations_2)

# %% [markdown]
# ### 6.3  Compare Woker Annotations to Majority Vote

# %%
def annotations_with_majority_vote(annotations, majority_votes):
    annotations_with_mv = annotations[["Input.query", "Input.id", "annotations_list", "gui_indexes_list", "WorkerId"]].set_index(['Input.id', 'Input.query']).join(majority_votes.set_index(['id', 'query']))
    annotations_with_mv = annotations_with_mv.reset_index()
    return annotations_with_mv

# %%
def annotations_with_majority_vote(annotations, majority_votes):
    annotations_int = annotations.copy()
    annotations_int = annotations_int.rename({"Input.id": "id", "Input.query": "query"}, axis=1)
    annotations_with_mv = annotations_int[["id", "query", "annotations_list", "gui_indexes_list", "WorkerId"]].set_index(['id', 'query']).join(majority_votes.set_index(['id', 'query']))
    annotations_with_mv = annotations_with_mv.reset_index()
    return annotations_with_mv

# %%
annotations_with_mv_1 = annotations_with_majority_vote(annotations_minified_1, majority_votes_1)
annotations_with_mv_2 = annotations_with_majority_vote(annotations_minified_2, majority_votes_2)

# %%
def agreement_to_mv(vote_worker, vote_majority):
    if len(vote_worker) != len(vote_majority):
        raise ValueError("Worker vote {} length unequal to majority vote {} length".format(len(vote_worker), len(vote_majority)))
    count_uneq_votes = 0
    for index, vote_m in enumerate(vote_majority):
        if not (vote_m == 3) and (vote_m) != vote_worker[index]:
            count_uneq_votes+=1
    return (len(vote_majority) - count_uneq_votes) / len(vote_majority)

# %%
def create_approvement_dataframe(dataframe, approve_margin):
    dataframe["mv_agreement"] = dataframe.apply(lambda row: agreement_to_mv(row["annotations_list"], row["relevance"]), axis=1)
    dataframe["state"] = dataframe.apply(lambda row: "accept" if row["mv_agreement"]>=APPROVE_MARGIN else "reject", axis=1)
    return dataframe

# %%
APPROVE_MARGIN = (10/15)
print("Approve margin : {}".format(APPROVE_MARGIN))
annotations_with_mv_1 = create_approvement_dataframe(annotations_with_mv_1, APPROVE_MARGIN)
annotations_with_mv_2 = create_approvement_dataframe(annotations_with_mv_2, APPROVE_MARGIN)
# Out:
# Approve margin : 0.6666666666666666

# %%
def create_final_approvement_dataframe(annotations_with_mv, annotations):
    annotations_with_mv_minified = annotations_with_mv[["id", "query", "WorkerId", "state", "mv_agreement"]]
    mturk_annotations = annotations.copy()
    mturk_annotations = mturk_annotations.drop(columns=['annotations_list', "gui_indexes_list"])
    # Merge original MTurk annotations dataframe with the approvement dataframe
    merged = pd.merge(mturk_annotations, annotations_with_mv_minified, left_on=["Input.id", "Input.query", "WorkerId"], right_on=["id", "query", "WorkerId"])
    # Fill the approve and reject cols according to the state cols
    merged["Approve"] = merged.apply(lambda row: "x" if row["state"] == "accept" else "", axis=1)
    merged["Reject"] = merged.apply(lambda row: ("You only matched {}% of the majority vote".format(row["mv_agreement"]*100)) if row["state"] == "reject" else "", axis=1)
    merged = merged.drop(columns=['mv_agreement', 'state', 'id', 'query'])
    return merged

# %%
merged_1 = create_final_approvement_dataframe(annotations_with_mv_1, annotations_1)
merged_2 = create_final_approvement_dataframe(annotations_with_mv_2, annotations_2)

# %%
abs_path_save = '../data/gui_ranking/mturk/goldstandard_batch_2/05_relevance_annotations/'
merged_1.to_csv(abs_path_save+"annotations_1_approval.csv", index=False)
merged_2.to_csv(abs_path_save+"annotations_2_approval.csv", index=False)

# %% [markdown]
# ## 6.4.1 Relevance Level Distributions

# %%
majority_votes_1 = majority_votes_1.reset_index()
majority_votes_2 = majority_votes_2.reset_index()
merged_majority_votes = majority_votes_1.copy().append(majority_votes_2)

# %%
merged_majority_votes = merged_majority_votes.copy().groupby(['id', 'query']).agg({
                                                                          "relevance": lambda x: list(x)[0] + list(x)[1],
                                                                          "gui_indexes": lambda x: list(x)[0] + list(x)[1]})
merged_majority_votes = merged_majority_votes.reset_index()

# %%
mv_analysis = merged_majority_votes.copy()
mv_analysis["count_0"] = mv_analysis.apply(lambda row: row['relevance'].count(0), axis=1)
mv_analysis["count_1"] = mv_analysis.apply(lambda row: row['relevance'].count(1), axis=1)
mv_analysis["count_2"] = mv_analysis.apply(lambda row: row['relevance'].count(2), axis=1)
mv_analysis["count_3"] = mv_analysis.apply(lambda row: row['relevance'].count(3), axis=1)

# %%
print("Mean num. of 0: {}".format(np.mean(mv_analysis['count_0'].values.tolist())))
print("Mean num. of 1: {}".format(np.mean(mv_analysis['count_1'].values.tolist())))
print("Mean num. of 2: {}".format(np.mean(mv_analysis['count_2'].values.tolist())))
print("Mean num. of 3: {}".format(np.mean(mv_analysis['count_3'].values.tolist())))
# Out:
# Mean num. of 0: 16.8
# Mean num. of 1: 4.08
# Mean num. of 2: 6.336666666666667
# Mean num. of 3: 2.783333333333333

# %%
mv_analysis['count_0'].plot.hist(bins=30)
mv_analysis['count_1'].plot.hist(bins=30, alpha=0.5)
mv_analysis['count_2'].plot.hist(bins=30, alpha=0.7)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
mv_analysis['count@1'] = mv_analysis.apply(lambda row: row['relevance'][0], axis=1)

# %%
count_at_1 = [elem[0] for elem in mv_analysis[['count@1']].values.tolist()]
num_queries = len(count_at_1)
print('Number of queries: {}'.format(num_queries))
print('Perc. of 2: {}'.format((count_at_1.count(2)/num_queries)))
print('Perc. of 1: {}'.format((count_at_1.count(1)/num_queries)))
print('Perc. of 2+1: {}'.format((count_at_1.count(2)/num_queries)+(count_at_1.count(1)/num_queries)))
print('Perc. of 0: {}'.format((count_at_1.count(0)/num_queries)))
print('Perc. of 3: {}'.format((count_at_1.count(3)/num_queries)))
# Out:
# Number of queries: 300
# Perc. of 2: 0.6833333333333333
# Perc. of 1: 0.03333333333333333
# Perc. of 2+1: 0.7166666666666667
# Perc. of 0: 0.14666666666666667
# Perc. of 3: 0.13666666666666666

# %% [markdown]
# ### 6.5 Compute Occurances for Inter-Annotator Agreement

# %%
annotations_minified_1_ = annotations_minified_1.copy()
annotations_minified_2_ = annotations_minified_2.copy()
# Compute for each dataframe the group id and the cumcount to be able to join them into a single dataframe
annotations_minified_1_['groupid'] = annotations_minified_1_.groupby(['Input.query', 'Input.id']).ngroup()
annotations_minified_1_['cumcount'] = annotations_minified_1_.groupby(['Input.query', 'Input.id']).cumcount()

annotations_minified_2_['groupid'] = annotations_minified_2_.groupby(['Input.query', 'Input.id']).ngroup()
annotations_minified_2_['cumcount'] = annotations_minified_2_.groupby(['Input.query', 'Input.id']).cumcount()

# %%
merged_annotations_minified = annotations_minified_1_.copy().append(annotations_minified_2_)

# %%
# Save all the annotations of individual workers
abs_path_save = '../data/gui_ranking/mturk/goldstandard_batch_2/06_final_dataset/'
merged_annotations_minified.to_csv(abs_path_save+'goldstandard_batch_2_full.csv', index=False)

# %%
merged_annotations_minified = merged_annotations_minified.copy().groupby(['groupid', 'cumcount']).agg({"Input.query": lambda x: list(x)[0],
                                                                                "Input.id": lambda x: list(x)[0],
                                                                          "annotations_list": lambda x: list(x)[0] + list(x)[1],
                                                                          "gui_indexes_list": lambda x: list(x)[0] + list(x)[1]})
merged_annotations_minified = merged_annotations_minified.reset_index()

# %%
annotations_for_agreement = merged_annotations_minified[["Input.id", "Input.query", "annotations_list", "gui_indexes_list"]].copy()

# %%
def compute_occurance_matrix(annotations):
    alls = []
    for gui_anno in annotations:
        counts = {0:0, 1:0, 2:0}
        for elem in gui_anno:
            counts[elem]+=1
        alls.append([counts[0], counts[1], counts[2]])
    return alls

def compute_occurance_zip(annotations):
    return list(zip(*annotations))

# %%
relevances = merged_majority_votes[["id", "query", "relevance"]].rename(columns={"id": "Input.id", 'query':'Input.query'})

# %%
agreement_counts = annotations_for_agreement.groupby(['Input.id', 'Input.query']).agg({"annotations_list": lambda x: compute_occurance_zip(x.tolist()),
                                                                       "gui_indexes_list": lambda x: list(x)[0]})
agreement_counts = agreement_counts.reset_index()
agreement_counts_mv = pd.merge(agreement_counts, relevances, left_on=["Input.id", 'Input.query'], right_on=["Input.id", 'Input.query'])

# %%
agreement_counts_mv["occurances"] = agreement_counts_mv.apply(lambda row: compute_occurance_matrix(row["annotations_list"]), axis=1)

# %%
# Save the final gold standard with relevance annotations
abs_path_save = '../data/gui_ranking/mturk/goldstandard_batch_2/06_final_dataset/'
agreement_counts_mv.to_csv(abs_path_save+'goldstandard_batch_2.csv', index=False)
